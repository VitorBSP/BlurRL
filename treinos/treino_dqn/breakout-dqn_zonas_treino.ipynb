# %%
import gymnasium as gym
import numpy as np
import cv2
import ale_py

from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecTransposeImage, VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.atari_wrappers import FireResetEnv
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
import glob
from datetime import datetime

# %%
gym.register_envs(ale_py)

# %%
log_dir = "./logs_breakout/"
os.makedirs(log_dir, exist_ok=True)

# %%
class WhitePatchBreakout(gym.Wrapper):
    def __init__(self, env, apply_patch=False, region=(20, 40, 30, 30)):
        super().__init__(env)
        self.apply_patch = apply_patch
        self.x, self.y, self.w, self.h = region

    def _paint_patch(self, img):
        if not self.apply_patch:
            return img
        
        # Copia para não alterar o buffer original inadvertidamente
        img = img.copy()
        
        # Detecta dimensões (pode ser 84x84 ou a resolução nativa no render)
        H, W = img.shape[:2]
        
        x, y, w, h = self.x, self.y, self.w, self.h
        
        # Garante que o desenho não exceda as bordas
        y_end = min(y + h, H)
        x_end = min(x + w, W)
        
        if y < y_end and x < x_end:
            # Pinta de branco (255). Funciona tanto para RGB quanto Grayscale se ajustado
            img[y:y_end, x:x_end] = 255
            
        return img

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._paint_patch(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._paint_patch(obs), reward, terminated, truncated, info

    def render(self):
        # Mágica para o vídeo: Pega o render original e aplica a mancha nele
        img = self.env.render()
        return self._paint_patch(img)

# %%
class BlurBreakout(gym.Wrapper):
    def __init__(self, env, apply_blur=False, region=(20, 40, 30, 30), ksize=21):
        super().__init__(env)
        self.apply_blur = apply_blur
        self.x, self.y, self.w, self.h = region
        self.ksize = ksize if ksize % 2 == 1 else ksize + 1

    def _apply_blur(self, img):
        if not self.apply_blur:
            return img
        
        img = img.copy()
        H, W = img.shape[:2]
        x, y, w, h = self.x, self.y, self.w, self.h
        
        y_end = min(y + h, H)
        x_end = min(x + w, W)
        
        if y < y_end and x < x_end:
            roi = img[y:y_end, x:x_end]
            # Aplica Gaussian Blur na região de interesse
            blurred_roi = cv2.GaussianBlur(roi, (self.ksize, self.ksize), 0)
            img[y:y_end, x:x_end] = blurred_roi
            
        return img

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._apply_blur(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._apply_blur(obs), reward, terminated, truncated, info
    
    def render(self):
        img = self.env.render()
        return self._apply_blur(img)

# %%
class GrayscaleWrapper(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        # Força explicitamente o shape (H, W, 1) para compatibilidade com SB3
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=(old_shape[0], old_shape[1], 1), dtype=np.uint8
        )

    def _convert(self, obs):
        # Se for RGB (3 canais), converte para Gray e mantém dimensão extra
        if obs.ndim == 3 and obs.shape[2] == 3:
            return cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)[:, :, None]
        return obs

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._convert(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._convert(obs), reward, terminated, truncated, info

# %%
def _create_base_gym_env(render_mode, with_modification, modification_type, log_dir=None):
    """
    Função interna para garantir que a ordem dos wrappers seja idêntica
    tanto no treino quanto no vídeo.
    """
    env = gym.make("ALE/Breakout-v5", render_mode=render_mode)
    
    # 1. Garante inicio do jogo
    env = FireResetEnv(env)
    
    # 2. Resize para 84x84 (Colorido)
    # façam sentido na imagem pequena.
    env = gym.wrappers.ResizeObservation(env, (84, 84))
    
    # 3. Aplica a Modificação Visual (Blur ou White Patch)
    if modification_type == 'white_patch':
        env = WhitePatchBreakout(env, apply_patch=with_modification, region=(20, 40, 30, 30))
    elif modification_type == 'blur':
        env = BlurBreakout(env, apply_blur=with_modification, region=(20, 40, 30, 30), ksize=21)
    

    if log_dir:
        env = Monitor(env, log_dir)
        
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', log_dir="./logs/"):
    """
    Cria o ambiente de treino.
    Agora gera um arquivo monitor com TIMESTAMP para não sobrescrever os anteriores.
    Ex: ./logs/monitor_20231027_153000.csv
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)
    
    # Gera o timestamp UMA VEZ para este ambiente
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    def _init():
        # 1. Base Environment
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        
        # 2. Fire Reset
        env = FireResetEnv(env)
        
        # 3. Resize PRIMEIRO (Para 84x84)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # 4. Aplica a Modificação (Blur ou White Patch)
        if change == 'white_patch':
            # Usa sua classe com apply_patch=with_blur
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=(20, 40, 30, 30))
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=(20, 40, 30, 30), ksize=21)
        
        # 5. Grayscale (Transforma em H, W, 1)
        env = GrayscaleWrapper(env)
        
        # 6. Monitor (AGORA COM TIMESTAMP NO NOME)
        if log_dir:
            # Cria o caminho: ./logs/monitor_20231123_220000
            # O SB3 adiciona .csv automaticamente na maioria das versões
            filename = os.path.join(log_dir, f"monitor_{timestamp}")
            env = Monitor(env, filename)
            
        return env

    # 7. Vetorização (SB3)
    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', log_dir="./logs/"):
    """
    Cria o ambiente de treino mantendo a consistência exata com o ambiente de avaliação.
    Parâmetros renomeados para bater com sua chamada: with_blur, change.
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)

    def _init():
        # 1. Base Environment
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        
        # 2. Fire Reset
        env = FireResetEnv(env)
        
        # 3. Resize PRIMEIRO (Para 84x84)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # 4. Aplica a Modificação (Blur ou White Patch)
        if change == 'white_patch':
            # Usa sua classe com apply_patch=with_blur
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=(20, 40, 30, 30))
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=(20, 40, 30, 30), ksize=21)
        
        # 5. Grayscale (Transforma em H, W, 1)
        env = GrayscaleWrapper(env)
        
        # 6. Monitor
        if log_dir:
            env = Monitor(env, log_dir)
            
        return env

    # 7. Vetorização (SB3)
    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', zone='middle', log_dir="./logs/"):
    """
    Cria ambiente com zonas configuráveis.
    Zonas disponíveis: 'top', 'middle', 'bottom'.
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)

    # Coordenadas fixas para 84x84 (Mantendo mancha de 30x30)
    # X=27 centraliza horizontalmente (84 - 30) / 2
    presets = {
        # ZONA 1: TOP (TIJOLOS)
        # Y=18 estava alto. Vamos para Y=24.
        # X=25 corrige o deslocamento para a esquerda.
        'top':    (60, 55, 40, 40), 

        # ZONA 2: MIDDLE (TRAJETÓRIA/REAÇÃO)
        # Y=40 cobre a área onde a bola corre antes de chegar no paddle.
        # Fica logo abaixo da massa principal de tijolos.
        'middle': (60, 110, 40, 40), 

        # ZONA 3: BOTTOM (PADDLE)
        # Y=44 garante que a mancha vá até o pixel 84 (fim da tela).
        # Cobre totalmente a área de movimento do paddle.
        'bottom': (60, 165, 40, 40)  
    }
    
    # Seleciona a região baseada no nome, ou usa 'middle' como padrão
    region = presets.get(zone, (27, 40, 30, 30))

    def _init():
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        env = FireResetEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # Aplica a mancha na zona escolhida
        if change == 'white_patch':
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=region)
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=region, ksize=21)
        
        env = GrayscaleWrapper(env)
        
        if log_dir:
            # Adiciona o nome da zona no log para diferenciar depois
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(log_dir, f"monitor_{zone}_{timestamp}")
            env = Monitor(env, filename)
            
        return env

    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def debug_visualize_zones():
    zones = ['top', 'middle', 'bottom']
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    for i, zone in enumerate(zones):
        # Cria ambiente temporário
        env = make_training_env(with_blur=True, change='white_patch', zone=zone, log_dir=None)
        
        env.reset()
        # Dá alguns passos para o jogo começar e a bola aparecer (se possível)
        for _ in range(5):
            obs, _, _, _ = env.step([1]) # Fire/Noop
            
        # Pega o render colorido interno (O que nós vemos)
        # O env é um VecEnv, então acessamos envs[0]
        img = env.envs[0].render()
        
        axes[i].imshow(img)
        axes[i].set_title(f"ZONA: {zone.upper()}\n(Mancha 40x40)")
        axes[i].axis('off')
        
        env.close()
    
    plt.tight_layout()
    plt.show()

# RODE ISSO AGORA:
debug_visualize_zones()

# %%
def make_training_env(with_blur=False, change='white_patch', zone='middle', log_dir="./logs/"):
    """
    Cria ambiente com zonas configuráveis.
    Zonas disponíveis: 'top', 'middle', 'bottom'.
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)

    # --- CORREÇÃO DE ESCALA ---
    # A imagem da IA tem apenas 84x84 pixels.
    # Tamanho da Mancha: 40x40 pixels.
    # Centralização X: (84 - 40) / 2 = 22.
    
    presets = {
        # ZONA 1: TOP (TIJOLOS)
        # Y=25: Centraliza a mancha na massa de tijolos coloridos.
        'top':    (32, 25, 20, 20), 

        # ZONA 2: MIDDLE (TRAJETÓRIA)
        # Y=50: Fica no espaço vazio logo acima da linha de perigo.
        'middle': (32, 50, 20, 20), 

        # ZONA 3: BOTTOM (PADDLE)
        # Y=64: Vai exatamente até o pixel 84 (64+20=84).
        # Cobre apenas o centro do paddle, exigindo precisão.
        'bottom': (32, 64, 20, 20)  
    }
    
    region = presets.get(zone, (22, 38, 40, 40))

    def _init():
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        env = FireResetEnv(env)
        
        # 1. Redimensiona PRIMEIRO (O mundo vira 84x84 aqui)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # 2. Aplica a Mancha DEPOIS (Usando as coordenadas convertidas acima)
        if change == 'white_patch':
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=region)
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=region, ksize=21)
        
        env = GrayscaleWrapper(env)
        
        if log_dir:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(log_dir, f"monitor_{zone}_{timestamp}")
            env = Monitor(env, filename)
            
        return env

    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def visualize_agent_view():
    zones = ['top', 'middle', 'bottom']
    
    # Cria uma figura com 3 subplots
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    for i, zone in enumerate(zones):
        print(f"Gerando visualização para a zona: {zone}...")
        
        # 1. Cria o ambiente com a zona específica
        # (Usa a função make_training_env que acabamos de corrigir)
        env = make_training_env(with_blur=True, change='white_patch', zone=zone, log_dir=None)
        
        obs = env.reset()
        
        # 2. Avança o jogo por 40 passos para garantir que:
        # - O jogo começou (FIRE)
        # - Os tijolos desceram (se for o caso)
        # - A bola apareceu
        for _ in range(40):
            # Envia ação 1 (FIRE) para iniciar, depois aleatório ou NOOP
            action = [1] 
            obs, _, _, _ = env.step(action)
            
        # 3. Extrai a imagem
        # O shape do obs é (1, 4, 84, 84) -> (Batch, Channels/Stack, Height, Width)
        # Pegamos o índice [0, 3, :, :] -> O último frame empilhado (o mais atual)
        frame_atual = obs[0, 3, :, :]
        
        # 4. Plota
        ax = axes[i]
        ax.imshow(frame_atual, cmap='gray', vmin=0, vmax=255)
        ax.set_title(f"ZONA: {zone.upper()}\n(Visão real da IA 84x84)", fontsize=12)
        
        # Adiciona linhas de grade para ajudar a contar pixels (opcional)
        ax.grid(color='red', linestyle='-', linewidth=0.5, alpha=0.3)
        ax.set_xticks(np.arange(0, 84, 10))
        ax.set_yticks(np.arange(0, 84, 10))
        
        env.close()

    plt.tight_layout()
    plt.show()

# Execute agora:
visualize_agent_view()
# Out:
# Gerando visualização para a zona: top...
# Gerando visualização para a zona: middle...
# Gerando visualização para a zona: bottom...

# %%
steps = 3_000_000

# %%
# DQN("CnnPolicy", 
#     env_blur, 
#     verbose=1,buffer_size=100_000,  
#     optimize_memory_usage=False,
#     learning_starts=50_000,
#     learning_rate=1e-4,
#     batch_size=32,
#     exploration_fraction=0.1,
#     exploration_final_eps=0.01,
#     train_freq=4,
#     target_update_interval=100,
#     gradient_steps=1,
#     tensorboard_log="./tensorboard_logs/")

# %%
# model_blur = DQN(
#     "CnnPolicy", 
#     env_blur, 
#     verbose=1, 
    
#     # 1. Memória (Buffer)
#     # Aumentar permite que o agente lembre de experiências mais antigas e variadas.
#     # Se der erro de memória RAM, diminua para 50_000 ou ative optimize_memory_usage=True
#     buffer_size=100_000,  
#     optimize_memory_usage=False, 

#     # 2. Quando começar a aprender
#     # Espere o buffer encher bastante antes de começar a atualizar os pesos.
#     # Isso evita overfitting em movimentos aleatórios iniciais.
#     learning_starts=50_000, 

#     # 3. Taxa de Aprendizado (Padrão Atari)
#     learning_rate=1e-4, 

#     # 4. Batch Size
#     # 32 é o clássico para Atari.
#     batch_size=32, 

#     # 5. Exploração (Epsilon-Greedy)
#     # exploration_fraction: Fração do total_timesteps que ele passa diminuindo a exploração.
#     # 0.1 (10%) de 1M steps = 100k steps explorando muito. 
#     exploration_fraction=0.1, 
#     # exploration_final_eps: No final, 1% de chance de movimento aleatório é melhor que 5% no Breakout.
#     exploration_final_eps=0.01, 

#     # 6. Frequência de Treino
#     # Treina a cada 4 passos do ambiente (Padrão do artigo Nature).
#     train_freq=4, 
    
#     # 7. Atualização da Rede Alvo (Estabilidade)
#     # A cada 1000 passos, copia os pesos para a rede alvo.
#     target_update_interval=1000, 
    
#     # 8. Gradiente
#     gradient_steps=1,
    
#     # (Opcional) Logs para Tensorboard (visualizar gráficos em tempo real)
#     tensorboard_log="./tensorboard_logs/"
# )

# %%
steps_total = 3_000_000  # Recomendado: 3 Milhões
# steps_total = 100_000  # Use este valor baixo SÓ se for testar se o código roda sem erro

# Lista de experimentos para rodar
# Formato: (Nome do Arquivo, Com Blur?, Qual Zona?)
experimentos = [
    ("dqn_breakout_normal",      False, "middle"), # Normal (Zona tanto faz pq with_blur=False)
    ("dqn_breakout_zone_top",    True,  "top"),    # Hipótese Planejamento
    ("dqn_breakout_zone_middle", True,  "middle"), # Hipótese Trajetória
    ("dqn_breakout_zone_bottom", True,  "bottom")  # Hipótese Propriocepção
]

print(f"--- INICIANDO BATERIA DE 4 TREINAMENTOS ---")
print(f"Total de Steps por agente: {steps_total}")
print(f"Estimativa de tempo total: ~{(steps_total * 4) / 350 / 3600:.1f} horas (a 350 FPS)\n")

for nome_modelo, usar_blur, zona in experimentos:
    
    start_time = time.time()
    
    # 1. Título bonito para o log
    tipo = "NORMAL (SEM MANCHA)" if not usar_blur else f"COM MANCHA - ZONA {zona.upper()}"
    print(f"\n{'='*60}")
    print(f" TREINANDO: {tipo}")
    print(f" Arquivo de saída: {nome_modelo}")
    print(f"{'='*60}")
    
    # 2. Define pasta de log única para cada um
    # Se for normal, pasta logs_normal, senão logs_hipotese_zona
    if not usar_blur:
        current_log_dir = "./logs_normal/"
    else:
        current_log_dir = f"./logs_hipotese_{zona}/"
    
    # 3. Cria o Ambiente
    # Nota: Se usar_blur=False, o parametro 'zone' é ignorado pela lógica interna, o que está correto.
    env = make_training_env(with_blur=usar_blur, change='white_patch', zone=zona, log_dir=current_log_dir)
    
    # 4. Define o Modelo (Hiperparâmetros idênticos para todos)
    model = DQN(
        "CnnPolicy", 
        env, 
        verbose=1,
        buffer_size=100_000,           # Buffer grande para memória
        optimize_memory_usage=False,   # True se tiver pouca RAM
        learning_starts=50_000,        # Coleta experiência antes de treinar
        learning_rate=1e-4,            # Padrão Atari
        batch_size=32,
        exploration_fraction=0.1,      # 10% do tempo explorando
        exploration_final_eps=0.01,    # 1% de chance de erro no final
        train_freq=4,
        target_update_interval=1000,   # Estabilidade
        gradient_steps=1,
        tensorboard_log=f"./tb_logs_{zona if usar_blur else 'normal'}/"
    )
    
    # 5. Treina
    try:
        model.learn(total_timesteps=steps_total)
        
        # 6. Salva
        model.save(nome_modelo)
        print(f"--> Modelo salvo: {nome_modelo}.zip")
        
    except Exception as e:
        print(f"!!! ERRO AO TREINAR {nome_modelo}: {e}")
        
    finally:
        # Garante que o ambiente fecha para liberar memória
        env.close()
        elapsed = (time.time() - start_time) / 3600
        print(f"--> Tempo decorrido neste agente: {elapsed:.2f} horas")

print("\n\n################################################")
print(" TODAS AS SESSÕES DE TREINAMENTO FORAM CONCLUÍDAS")
print("################################################")
# Out:
# --- INICIANDO BATERIA DE 4 TREINAMENTOS ---
# Total de Steps por agente: 3000000
# Estimativa de tempo total: ~9.5 horas (a 350 FPS)
#
#
# ============================================================
#  TREINANDO: NORMAL (SEM MANCHA)
#  Arquivo de saída: dqn_breakout_normal
# ============================================================
# Using cpu device
# Logging to ./tb_logs_normal/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1527     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 785      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1472     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1463     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 0.938    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1456     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1439     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1425     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1420     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1414     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1412     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1412     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1407     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1405     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1408     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1409     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1407     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1406     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1409     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1408     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1408     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1406     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1405     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1403     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1402     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1402     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1402     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1401     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1404     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1401     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1402     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1404     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20778    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1405     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 21682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1405     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1405     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 23088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1406     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1407     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.1      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1408     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 25110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1408     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1406     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1406     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 27171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1405     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1403     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1402     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1402     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1400     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1400     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 31259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1401     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 32005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1401     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 32759    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1399     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 33403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1399     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 34159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1400     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 34940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1400     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 35801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1399     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 36407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1400     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 36978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1399     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 37820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1399     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 38497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1400     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 39293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1400     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 40154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1400     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 40867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1400     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 41554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1400     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 42144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1400     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 42689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1400     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 43352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1400     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 43977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1401     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 44648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1401     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 45370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1401     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 46210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1403     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 46951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1401     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 47598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1401     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 48183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1402     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 48992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1402     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 49650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1316     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 50417    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.91e-05 |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1178     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 51312    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04e-05 |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1081     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 52095    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 523      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1029     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 52603    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.62e-05 |
# |    n_updates        | 650      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 952      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 53468    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16e-05 |
# |    n_updates        | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 902      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 54100    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000427 |
# |    n_updates        | 1024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 856      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 54765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07e-05 |
# |    n_updates        | 1191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 814      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 55470    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.98e-05 |
# |    n_updates        | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 781      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 56102    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 1525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 743      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 56910    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99e-06 |
# |    n_updates        | 1727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 711      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 57683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000505 |
# |    n_updates        | 1920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 681      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 58464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02e-05 |
# |    n_updates        | 2115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 658      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 59103    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 2275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 635      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 59852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-05 |
# |    n_updates        | 2462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 616      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 60494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 2623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 596      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 61150    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 2787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 575      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 61931    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000639 |
# |    n_updates        | 2982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 554      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 62769    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000554 |
# |    n_updates        | 3192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 539      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 63357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00175  |
# |    n_updates        | 3339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 523      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 64120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00419  |
# |    n_updates        | 3529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 507      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 64914    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000367 |
# |    n_updates        | 3728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 490      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 65857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 3964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 478      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 66602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000317 |
# |    n_updates        | 4150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 466      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 67428    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00134  |
# |    n_updates        | 4356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 456      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 68170    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00448  |
# |    n_updates        | 4542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 447      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 68868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00386  |
# |    n_updates        | 4716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 441      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 69397    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000164 |
# |    n_updates        | 4849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 432      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 70142    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000286 |
# |    n_updates        | 5035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 423      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 70943    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000368 |
# |    n_updates        | 5235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 416      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 71608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00136  |
# |    n_updates        | 5401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 409      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 72350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00121  |
# |    n_updates        | 5587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 401      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 73112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000418 |
# |    n_updates        | 5777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 395      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 73858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00436  |
# |    n_updates        | 5964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 388      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 74702    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000245 |
# |    n_updates        | 6175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 383      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 75354    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000634 |
# |    n_updates        | 6338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 377      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 76085    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00645  |
# |    n_updates        | 6521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 370      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 77021    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00863  |
# |    n_updates        | 6755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 366      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 77703    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00242  |
# |    n_updates        | 6925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 361      |
# |    time_elapsed     | 216      |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6624     |
# |    fps              | 140      |
# |    time_elapsed     | 20884    |
# |    total_timesteps  | 2938809  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00853  |
# |    n_updates        | 722202   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 487      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6628     |
# |    fps              | 140      |
# |    time_elapsed     | 20894    |
# |    total_timesteps  | 2940304  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 722575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 483      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6632     |
# |    fps              | 140      |
# |    time_elapsed     | 20905    |
# |    total_timesteps  | 2941901  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 722975   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 493      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6636     |
# |    fps              | 140      |
# |    time_elapsed     | 20925    |
# |    total_timesteps  | 2944702  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00454  |
# |    n_updates        | 723675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 499      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6640     |
# |    fps              | 140      |
# |    time_elapsed     | 20944    |
# |    total_timesteps  | 2947501  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0057   |
# |    n_updates        | 724375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 502      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6644     |
# |    fps              | 140      |
# |    time_elapsed     | 20957    |
# |    total_timesteps  | 2949322  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 724830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 497      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6648     |
# |    fps              | 140      |
# |    time_elapsed     | 20969    |
# |    total_timesteps  | 2951082  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 725270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 499      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6652     |
# |    fps              | 140      |
# |    time_elapsed     | 20982    |
# |    total_timesteps  | 2953004  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00538  |
# |    n_updates        | 725750   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 491      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6656     |
# |    fps              | 140      |
# |    time_elapsed     | 20995    |
# |    total_timesteps  | 2954828  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00447  |
# |    n_updates        | 726206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6660     |
# |    fps              | 140      |
# |    time_elapsed     | 21006    |
# |    total_timesteps  | 2956379  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 726594   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 486      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6664     |
# |    fps              | 140      |
# |    time_elapsed     | 21017    |
# |    total_timesteps  | 2957967  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0816   |
# |    n_updates        | 726991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 484      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6668     |
# |    fps              | 140      |
# |    time_elapsed     | 21029    |
# |    total_timesteps  | 2959633  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 727408   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 499      |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6672     |
# |    fps              | 140      |
# |    time_elapsed     | 21052    |
# |    total_timesteps  | 2962973  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0631   |
# |    n_updates        | 728243   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 506      |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6676     |
# |    fps              | 140      |
# |    time_elapsed     | 21067    |
# |    total_timesteps  | 2965193  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 728798   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 509      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6680     |
# |    fps              | 140      |
# |    time_elapsed     | 21082    |
# |    total_timesteps  | 2967301  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00728  |
# |    n_updates        | 729325   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 526      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6684     |
# |    fps              | 140      |
# |    time_elapsed     | 21106    |
# |    total_timesteps  | 2970746  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 730186   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 509      |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6688     |
# |    fps              | 140      |
# |    time_elapsed     | 21120    |
# |    total_timesteps  | 2972697  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 730674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 506      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6692     |
# |    fps              | 140      |
# |    time_elapsed     | 21132    |
# |    total_timesteps  | 2974551  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 731137   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 506      |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6696     |
# |    fps              | 140      |
# |    time_elapsed     | 21144    |
# |    total_timesteps  | 2976216  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 731553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 510      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6700     |
# |    fps              | 140      |
# |    time_elapsed     | 21159    |
# |    total_timesteps  | 2978351  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 732087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 513      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6704     |
# |    fps              | 140      |
# |    time_elapsed     | 21173    |
# |    total_timesteps  | 2980361  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00781  |
# |    n_updates        | 732590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 510      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6708     |
# |    fps              | 140      |
# |    time_elapsed     | 21184    |
# |    total_timesteps  | 2981944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 732985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 523      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6712     |
# |    fps              | 140      |
# |    time_elapsed     | 21205    |
# |    total_timesteps  | 2985000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0465   |
# |    n_updates        | 733749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6716     |
# |    fps              | 140      |
# |    time_elapsed     | 21225    |
# |    total_timesteps  | 2987867  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00879  |
# |    n_updates        | 734466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 528      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6720     |
# |    fps              | 140      |
# |    time_elapsed     | 21239    |
# |    total_timesteps  | 2989799  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0566   |
# |    n_updates        | 734949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 530      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6724     |
# |    fps              | 140      |
# |    time_elapsed     | 21253    |
# |    total_timesteps  | 2991826  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 735456   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 528      |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6728     |
# |    fps              | 140      |
# |    time_elapsed     | 21262    |
# |    total_timesteps  | 2993154  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00846  |
# |    n_updates        | 735788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 532      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6732     |
# |    fps              | 140      |
# |    time_elapsed     | 21275    |
# |    total_timesteps  | 2995074  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 736268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 517      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6736     |
# |    fps              | 140      |
# |    time_elapsed     | 21284    |
# |    total_timesteps  | 2996404  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00607  |
# |    n_updates        | 736600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 507      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6740     |
# |    fps              | 140      |
# |    time_elapsed     | 21297    |
# |    total_timesteps  | 2998194  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 737048   |
# ----------------------------------
# --> Modelo salvo: dqn_breakout_zone_bottom.zip
# --> Tempo decorrido neste agente: 5.92 horas
#
#
# ################################################
#  TODAS AS SESSÕES DE TREINAMENTO FORAM CONCLUÍDAS
# ################################################

# %%
# print("--- Iniciando Treino SEM Blur ---")
# env_normal = make_training_env(with_blur=False, change = 'white_patch', log_dir=log_dir_clean)
# # model_normal = DQN("CnnPolicy", env_normal, verbose=1, buffer_size=50_000, learning_starts=10_000, train_freq=4) 
# model_normal = DQN("CnnPolicy", 
#     env_normal, 
#     verbose=1,buffer_size=100_000,  
#     optimize_memory_usage=False,
#     learning_starts=50_000,
#     learning_rate=1e-4,
#     batch_size=32,
#     exploration_fraction=0.1,
#     exploration_final_eps=0.01,
#     train_freq=4,
#     target_update_interval=1000,
#     gradient_steps=1)

# model_normal.learn(total_timesteps=steps) # Baixo para teste rápido
# model_normal.save("dqn_breakout_normal")
# env_normal.close()

# %%
# # Configuração
# steps_por_zona = steps  # Ajuste conforme seu tempo disponível
# zonas = ['top', 'middle', 'bottom']

# for zona in zonas:
#     print(f"\n=============================================")
#     print(f" INICIANDO TREINO: ZONA {zona.upper()}")
#     print(f"=============================================")
    
#     # Define diretório de log específico para não misturar
#     log_dir = f"./logs_hipotese_{zona}/"
    
#     # Cria ambiente na zona específica
#     env = make_training_env(with_blur=True, change='white_patch', zone=zona, log_dir=log_dir)
    
#     # Cria Modelo DQN (Configuração Otimizada que definimos antes)
#     model = DQN(
#         "CnnPolicy", 
#         env, 
#         verbose=1,buffer_size=100_000,
#         optimize_memory_usage=False,
#         learning_starts=50_000,
#         learning_rate=1e-4,
#         batch_size=32,
#         exploration_fraction=0.1,
#         exploration_final_eps=0.01,
#         train_freq=4,
#         target_update_interval=1000,
#         gradient_steps=1
#         )
    
#     # Treina
#     model.learn(total_timesteps=steps_por_zona)
    
#     # Salva com nome distinto
#     model.save(f"dqn_breakout_zone_{zona}")
    
#     env.close()
#     print(f"Modelo da zona {zona} salvo com sucesso!")

# print("\n--- Todos os experimentos finalizados ---")

# %%
# def record_video(model, name_prefix, with_blur, change='white_patch', zone='middle', n_episodes=1, max_steps=3000):
#     video_folder = "./videos/"
#     os.makedirs(video_folder, exist_ok=True)
    
#     print(f"--- Gravando {name_prefix} [Zona: {zone}] (Max {max_steps} steps) ---")

#     # Coordenadas das zonas (Devem ser IDÊNTICAS ao treino)
#     presets = {
#         # ZONA 1: TIJOLOS (Y=22)
#         # Cobre a maioria das linhas coloridas.
#         'top':    (27, 22, 30, 30), 

#         # ZONA 2: TRAJETÓRIA/VAZIO (Y=48)
#         # Fica entre os tijolos e o paddle. Onde a bola corre livre.
#         'middle': (27, 48, 30, 30), 

#         # ZONA 3: PADDLE/AGENTE (Y=54)
#         # Vai do pixel 54 até 84 (fim da tela). Cobre o agente totalmente.
#         'bottom': (27, 54, 30, 30)  
#     }
#     region = presets.get(zone, (27, 40, 30, 30))

#     def _create_video_env():
#         env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
#         env = FireResetEnv(env)
#         env = gym.wrappers.ResizeObservation(env, (84, 84))
        
#         # Aplica a mancha na zona correta
#         if change == 'white_patch':
#             env = WhitePatchBreakout(env, apply_patch=with_blur, region=region)
#         elif change == 'blur':
#             env = BlurBreakout(env, apply_blur=with_blur, region=region, ksize=21)
        
#         env = gym.wrappers.RecordVideo(
#             env, 
#             video_folder=video_folder, 
#             name_prefix=name_prefix,
#             episode_trigger=lambda x: True,
#             disable_logger=True
#         )
        
#         env = GrayscaleWrapper(env)
#         return env

#     env = DummyVecEnv([_create_video_env])
#     env = VecTransposeImage(env)
#     env = VecFrameStack(env, n_stack=4)

#     obs = env.reset()
#     episodes_count = 0
#     current_steps = 0
#     last_lives = 5 
    
#     try:
#         while episodes_count < n_episodes:
#             action, _ = model.predict(obs, deterministic=True)
            
#             # --- Anti-Stuck: Força FIRE se ficar parado demais ---
#             # (Mantenha sua lógica de vidas ou use um contador de ações repetidas)
            
#             obs, rewards, done, infos = env.step(action)
#             current_steps += 1
            
#             # Checagem de vidas para atualizar last_lives
#             for info in infos:
#                 lives = info.get("lives", 0)
#                 if lives < last_lives:
#                     last_lives = lives
            
#             if current_steps > max_steps:
#                 print(f"ALERTA: Episódio excedeu {max_steps} passos. Forçando parada.")
#                 done = [True]
            
#             for i, d in enumerate(done):
#                 if d:
#                     episodes_count += 1
#                     current_steps = 0
#                     last_lives = 5
#                     score = infos[i].get('episode', {}).get('r', 0)
#                     print(f"Episódio {episodes_count} finalizado | Score: {score}")
#                     obs = env.reset()
                    
#     except KeyboardInterrupt:
#         print("Interrompido.")
#     finally:
#         env.close()
#         print(f"Vídeos salvos em {video_folder}")

# %%
# if os.path.exists("dqn_breakout_zone_top.zip"):
#     print(">>> Carregando Modelo TOP...")
#     model_top = DQN.load("dqn_breakout_zone_top")
    
#     record_video(
#         model=model_top, 
#         name_prefix="video_teste_TOP", 
#         with_blur=True, 
#         change='white_patch', 
#         zone='top',  # <--- IMPORTANTE: Mudar para 'top'
#         n_episodes=2
#     )
# Out:
# >>> Carregando Modelo TOP...
# --- Gravando video_teste_TOP [Zona: top] (Max 3000 steps) ---
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\buffers.py:242: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.65GB > 4.34GB
#   warnings.warn(
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\user\Documents\mestrado\BlurRL\treino_dqn\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episódio 1 finalizado | Score: 0
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 2 finalizado | Score: 0
# Vídeos salvos em ./videos/

# %%
# if os.path.exists("dqn_breakout_zone_middle.zip"): # Ou o nome que você usou antes
#     print("\n>>> Carregando Modelo MIDDLE...")
#     model_middle = DQN.load("dqn_breakout_zone_middle")
    
#     record_video(
#         model=model_middle, 
#         name_prefix="video_teste_MIDDLE", 
#         with_blur=True, 
#         change='white_patch', 
#         zone='middle', 
#         n_episodes=2
#     )
# Out:
# >>> Carregando Modelo MIDDLE...
# --- Gravando video_teste_MIDDLE [Zona: middle] (Max 3000 steps) ---
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\buffers.py:242: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.65GB > 4.23GB
#   warnings.warn(
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 1 finalizado | Score: 0
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 2 finalizado | Score: 0
# Vídeos salvos em ./videos/

# %%
# record_video(model_blur, "teste_com_blur", with_blur=True, change = 'white_patch', n_episodes=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 record_video(model_blur, "teste_com_blur", with_blur=True, change = 'white_patch', n_episodes=5)
#
# NameError: name 'model_blur' is not defined

# %%
# record_video(model_normal, "teste_sem_blur", with_blur=False, change = 'white_patch', n_episodes=5, max_steps=100_000)
# Out:
# --- Gravando teste_sem_blur (Max 100000 steps) ---
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\user\Documents\mestrado\BlurRL\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episódio 1 finalizado | Score: 0
# Episódio 2 finalizado | Score: 0
# Episódio 3 finalizado | Score: 0
# Episódio 4 finalizado | Score: 0
# Episódio 5 finalizado | Score: 0
# Vídeos salvos em ./videos/
