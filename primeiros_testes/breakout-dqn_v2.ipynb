# %%
import gymnasium as gym
import numpy as np
import cv2
import ale_py

from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecTransposeImage, VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.atari_wrappers import FireResetEnv
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import glob
from datetime import datetime

# %%
gym.register_envs(ale_py)

# %%
log_dir = "./logs_breakout/"
os.makedirs(log_dir, exist_ok=True)

# %%
class WhitePatchBreakout(gym.Wrapper):
    def __init__(self, env, apply_patch=False, region=(20, 40, 30, 30)):
        super().__init__(env)
        self.apply_patch = apply_patch
        self.x, self.y, self.w, self.h = region

    def _paint_patch(self, img):
        if not self.apply_patch:
            return img
        
        # Copia para não alterar o buffer original inadvertidamente
        img = img.copy()
        
        # Detecta dimensões (pode ser 84x84 ou a resolução nativa no render)
        H, W = img.shape[:2]
        
        x, y, w, h = self.x, self.y, self.w, self.h
        
        # Garante que o desenho não exceda as bordas
        y_end = min(y + h, H)
        x_end = min(x + w, W)
        
        if y < y_end and x < x_end:
            # Pinta de branco (255). Funciona tanto para RGB quanto Grayscale se ajustado
            img[y:y_end, x:x_end] = 255
            
        return img

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._paint_patch(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._paint_patch(obs), reward, terminated, truncated, info

    def render(self):
        # Mágica para o vídeo: Pega o render original e aplica a mancha nele
        img = self.env.render()
        return self._paint_patch(img)

# %%
class BlurBreakout(gym.Wrapper):
    def __init__(self, env, apply_blur=False, region=(20, 40, 30, 30), ksize=21):
        super().__init__(env)
        self.apply_blur = apply_blur
        self.x, self.y, self.w, self.h = region
        self.ksize = ksize if ksize % 2 == 1 else ksize + 1

    def _apply_blur(self, img):
        if not self.apply_blur:
            return img
        
        img = img.copy()
        H, W = img.shape[:2]
        x, y, w, h = self.x, self.y, self.w, self.h
        
        y_end = min(y + h, H)
        x_end = min(x + w, W)
        
        if y < y_end and x < x_end:
            roi = img[y:y_end, x:x_end]
            # Aplica Gaussian Blur na região de interesse
            blurred_roi = cv2.GaussianBlur(roi, (self.ksize, self.ksize), 0)
            img[y:y_end, x:x_end] = blurred_roi
            
        return img

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._apply_blur(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._apply_blur(obs), reward, terminated, truncated, info
    
    def render(self):
        img = self.env.render()
        return self._apply_blur(img)

# %%
class GrayscaleWrapper(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        # Força explicitamente o shape (H, W, 1) para compatibilidade com SB3
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=(old_shape[0], old_shape[1], 1), dtype=np.uint8
        )

    def _convert(self, obs):
        # Se for RGB (3 canais), converte para Gray e mantém dimensão extra
        if obs.ndim == 3 and obs.shape[2] == 3:
            return cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)[:, :, None]
        return obs

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._convert(obs), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._convert(obs), reward, terminated, truncated, info

# %%
def _create_base_gym_env(render_mode, with_modification, modification_type, log_dir=None):
    """
    Função interna para garantir que a ordem dos wrappers seja idêntica
    tanto no treino quanto no vídeo.
    """
    env = gym.make("ALE/Breakout-v5", render_mode=render_mode)
    
    # 1. Garante inicio do jogo
    env = FireResetEnv(env)
    
    # 2. Resize para 84x84 (Colorido)
    # façam sentido na imagem pequena.
    env = gym.wrappers.ResizeObservation(env, (84, 84))
    
    # 3. Aplica a Modificação Visual (Blur ou White Patch)
    if modification_type == 'white_patch':
        env = WhitePatchBreakout(env, apply_patch=with_modification, region=(20, 40, 30, 30))
    elif modification_type == 'blur':
        env = BlurBreakout(env, apply_blur=with_modification, region=(20, 40, 30, 30), ksize=21)
    

    if log_dir:
        env = Monitor(env, log_dir)
        
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', log_dir="./logs/"):
    """
    Cria o ambiente de treino.
    Agora gera um arquivo monitor com TIMESTAMP para não sobrescrever os anteriores.
    Ex: ./logs/monitor_20231027_153000.csv
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)
    
    # Gera o timestamp UMA VEZ para este ambiente
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    def _init():
        # 1. Base Environment
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        
        # 2. Fire Reset
        env = FireResetEnv(env)
        
        # 3. Resize PRIMEIRO (Para 84x84)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # 4. Aplica a Modificação (Blur ou White Patch)
        if change == 'white_patch':
            # Usa sua classe com apply_patch=with_blur
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=(20, 40, 30, 30))
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=(20, 40, 30, 30), ksize=21)
        
        # 5. Grayscale (Transforma em H, W, 1)
        env = GrayscaleWrapper(env)
        
        # 6. Monitor (AGORA COM TIMESTAMP NO NOME)
        if log_dir:
            # Cria o caminho: ./logs/monitor_20231123_220000
            # O SB3 adiciona .csv automaticamente na maioria das versões
            filename = os.path.join(log_dir, f"monitor_{timestamp}")
            env = Monitor(env, filename)
            
        return env

    # 7. Vetorização (SB3)
    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', log_dir="./logs/"):
    """
    Cria o ambiente de treino mantendo a consistência exata com o ambiente de avaliação.
    Parâmetros renomeados para bater com sua chamada: with_blur, change.
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)

    def _init():
        # 1. Base Environment
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        
        # 2. Fire Reset
        env = FireResetEnv(env)
        
        # 3. Resize PRIMEIRO (Para 84x84)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # 4. Aplica a Modificação (Blur ou White Patch)
        if change == 'white_patch':
            # Usa sua classe com apply_patch=with_blur
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=(20, 40, 30, 30))
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=(20, 40, 30, 30), ksize=21)
        
        # 5. Grayscale (Transforma em H, W, 1)
        env = GrayscaleWrapper(env)
        
        # 6. Monitor
        if log_dir:
            env = Monitor(env, log_dir)
            
        return env

    # 7. Vetorização (SB3)
    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
def make_training_env(with_blur=False, change='white_patch', zone='middle', log_dir="./logs/"):
    """
    Cria ambiente com zonas configuráveis.
    Zonas disponíveis: 'top', 'middle', 'bottom'.
    """
    if log_dir:
        os.makedirs(log_dir, exist_ok=True)

    # Coordenadas fixas para 84x84 (Mantendo mancha de 30x30)
    # X=27 centraliza horizontalmente (84 - 30) / 2
    presets = {
        'top':    (27, 10, 30, 30), # Cobre os tijolos
        'middle': (27, 40, 30, 30), # Cobre a trajetória (Sua config original)
        'bottom': (27, 54, 30, 30)  # Cobre o Paddle (Agente)
    }
    
    # Seleciona a região baseada no nome, ou usa 'middle' como padrão
    region = presets.get(zone, (27, 40, 30, 30))

    def _init():
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        env = FireResetEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # Aplica a mancha na zona escolhida
        if change == 'white_patch':
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=region)
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=region, ksize=21)
        
        env = GrayscaleWrapper(env)
        
        if log_dir:
            # Adiciona o nome da zona no log para diferenciar depois
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(log_dir, f"monitor_{zone}_{timestamp}")
            env = Monitor(env, filename)
            
        return env

    env = DummyVecEnv([_init])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)
    
    return env

# %%
log_dir_clean = "./logs_clean/"   # Pasta para o treino NORMAL
log_dir_patch = "./logs_patch/"   # Pasta para o treino COM MANCHA

# %%
steps = 3_000_000

# %%
# DQN("CnnPolicy", 
#     env_blur, 
#     verbose=1,buffer_size=100_000,  
#     optimize_memory_usage=False,
#     learning_starts=50_000,
#     learning_rate=1e-4,
#     batch_size=32,
#     exploration_fraction=0.1,
#     exploration_final_eps=0.01,
#     train_freq=4,
#     target_update_interval=100,
#     gradient_steps=1,
#     tensorboard_log="./tensorboard_logs/")

# %%
# model_blur = DQN(
#     "CnnPolicy", 
#     env_blur, 
#     verbose=1, 
    
#     # 1. Memória (Buffer)
#     # Aumentar permite que o agente lembre de experiências mais antigas e variadas.
#     # Se der erro de memória RAM, diminua para 50_000 ou ative optimize_memory_usage=True
#     buffer_size=100_000,  
#     optimize_memory_usage=False, 

#     # 2. Quando começar a aprender
#     # Espere o buffer encher bastante antes de começar a atualizar os pesos.
#     # Isso evita overfitting em movimentos aleatórios iniciais.
#     learning_starts=50_000, 

#     # 3. Taxa de Aprendizado (Padrão Atari)
#     learning_rate=1e-4, 

#     # 4. Batch Size
#     # 32 é o clássico para Atari.
#     batch_size=32, 

#     # 5. Exploração (Epsilon-Greedy)
#     # exploration_fraction: Fração do total_timesteps que ele passa diminuindo a exploração.
#     # 0.1 (10%) de 1M steps = 100k steps explorando muito. 
#     exploration_fraction=0.1, 
#     # exploration_final_eps: No final, 1% de chance de movimento aleatório é melhor que 5% no Breakout.
#     exploration_final_eps=0.01, 

#     # 6. Frequência de Treino
#     # Treina a cada 4 passos do ambiente (Padrão do artigo Nature).
#     train_freq=4, 
    
#     # 7. Atualização da Rede Alvo (Estabilidade)
#     # A cada 1000 passos, copia os pesos para a rede alvo.
#     target_update_interval=1000, 
    
#     # 8. Gradiente
#     gradient_steps=1,
    
#     # (Opcional) Logs para Tensorboard (visualizar gráficos em tempo real)
#     tensorboard_log="./tensorboard_logs/"
# )

# %%
print("--- Iniciando Treino SEM Blur ---")
env_normal = make_training_env(with_blur=False, change = 'white_patch', log_dir=log_dir_clean)
# model_normal = DQN("CnnPolicy", env_normal, verbose=1, buffer_size=50_000, learning_starts=10_000, train_freq=4) 
model_normal = DQN("CnnPolicy", 
    env_normal, 
    verbose=1,buffer_size=100_000,  
    optimize_memory_usage=False,
    learning_starts=50_000,
    learning_rate=1e-4,
    batch_size=32,
    exploration_fraction=0.1,
    exploration_final_eps=0.01,
    train_freq=4,
    target_update_interval=1000,
    gradient_steps=1)

model_normal.learn(total_timesteps=steps) # Baixo para teste rápido
model_normal.save("dqn_breakout_normal")
env_normal.close()
# Out:
# --- Iniciando Treino SEM Blur ---
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1432     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 723      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1466     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1407     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1397     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 0.9      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1375     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1368     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1384     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | 0.969    |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1391     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1398     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1392     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1383     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 0.938    |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1388     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8090     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1397     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1402     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.1      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1408     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1414     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1418     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1423     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1427     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1430     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 14272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1435     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1438     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 15587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1441     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1445     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1431     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1427     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1425     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1430     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1433     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1435     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 21648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1436     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1438     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 23118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1439     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 23667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1440     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1443     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 25194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1446     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 25912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1446     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1448     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 27544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1449     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1450     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 29476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1451     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1452     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1451     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 31491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1450     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 32148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1452     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 33056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1454     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 33814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1454     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 34403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1456     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 35276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1458     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 36237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1460     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 36950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1457     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 37613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1455     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 38227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1455     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 39019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1450     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 39748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1446     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 40494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1446     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 41598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.51     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1447     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 42245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.59     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1447     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 43183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1447     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 43849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.54     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1447     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 44452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.52     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1446     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 45053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1447     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 45760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1448     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 46464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1448     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 47094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1448     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 47791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1449     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 48540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1449     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 49330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1450     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 49992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1298     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 50737    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.59e-05 |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1183     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 51447    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58e-05 |
# |    n_updates        | 361      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1074     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 52358    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 589      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1006     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 53033    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1e-05  |
# |    n_updates        | 758      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 954      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 53642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.62e-06 |
# |    n_updates        | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 891      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 54507    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.59e-05 |
# |    n_updates        | 1126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 831      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 55372    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.15e-06 |
# |    n_updates        | 1342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 784      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 56127    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54e-05 |
# |    n_updates        | 1531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 747      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 56868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.32e-06 |
# |    n_updates        | 1716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 724      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 57406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.29e-05 |
# |    n_updates        | 1851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 696      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 58130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.92e-05 |
# |    n_updates        | 2032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 672      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 58774    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.09e-05 |
# |    n_updates        | 2193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 651      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 59425    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 2356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 625      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 60232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.16e-05 |
# |    n_updates        | 2557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 601      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 61024    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000488 |
# |    n_updates        | 2755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 585      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 61667    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000263 |
# |    n_updates        | 2916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 570      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 62336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 3083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 553      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 63090    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 3272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 533      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 64044    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000364 |
# |    n_updates        | 3510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 516      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 64958    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000172 |
# |    n_updates        | 3739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 505      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 65618    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000295 |
# |    n_updates        | 3904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 492      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 66476    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 4118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 482      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 67199    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 4299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 471      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 68101    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000442 |
# |    n_updates        | 4525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 461      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 68832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000556 |
# |    n_updates        | 4707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 452      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 69592    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000236 |
# |    n_updates        | 4897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.54     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 442      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 70436    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000982 |
# |    n_updates        | 5108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.51     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 434      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 71226    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000623 |
# |    n_updates        | 5306     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.52     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 426      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 71954    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 5488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 419      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 72701    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00022  |
# |    n_updates        | 5675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 414      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 73294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00183  |
# |    n_updates        | 5823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 406      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 74248    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00597  |
# |    n_updates        | 6061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 401      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 74947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00133  |
# |    n_updates        | 6236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 396      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 75582    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00232  |
# |    n_updates        | 6395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.51     |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 389      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 76406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00274  |
# |    n_updates        | 6601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 385      |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 77003    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000439 |
# |    n_updates        | 6750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 380      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 77713    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000325 |
# |    n_updates        | 6928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 376      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 78337    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00135  |
# |    n_updates        | 7084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 372      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 79005    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 7251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 367      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 79796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 7448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.54     |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 361      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 80740    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00352  |
# |    n_updates        | 7684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.731    |
# | time/               |          |
# ...
# |    time_elapsed     | 30297    |
# |    total_timesteps  | 2926190  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00595  |
# |    n_updates        | 719047   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 603      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5336     |
# |    fps              | 96       |
# |    time_elapsed     | 30312    |
# |    total_timesteps  | 2928351  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 719587   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5340     |
# |    fps              | 96       |
# |    time_elapsed     | 30327    |
# |    total_timesteps  | 2930564  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00858  |
# |    n_updates        | 720140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 598      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5344     |
# |    fps              | 96       |
# |    time_elapsed     | 30345    |
# |    total_timesteps  | 2933045  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00463  |
# |    n_updates        | 720761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5348     |
# |    fps              | 96       |
# |    time_elapsed     | 30361    |
# |    total_timesteps  | 2935414  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0041   |
# |    n_updates        | 721353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5352     |
# |    fps              | 96       |
# |    time_elapsed     | 30376    |
# |    total_timesteps  | 2937445  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 721861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 594      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5356     |
# |    fps              | 96       |
# |    time_elapsed     | 30392    |
# |    total_timesteps  | 2939788  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00882  |
# |    n_updates        | 722446   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 595      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5360     |
# |    fps              | 96       |
# |    time_elapsed     | 30411    |
# |    total_timesteps  | 2942450  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00428  |
# |    n_updates        | 723112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5364     |
# |    fps              | 96       |
# |    time_elapsed     | 30429    |
# |    total_timesteps  | 2944957  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00602  |
# |    n_updates        | 723739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 597      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5368     |
# |    fps              | 96       |
# |    time_elapsed     | 30444    |
# |    total_timesteps  | 2947146  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00501  |
# |    n_updates        | 724286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 598      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5372     |
# |    fps              | 96       |
# |    time_elapsed     | 30460    |
# |    total_timesteps  | 2949333  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0056   |
# |    n_updates        | 724833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5376     |
# |    fps              | 96       |
# |    time_elapsed     | 30473    |
# |    total_timesteps  | 2951194  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00665  |
# |    n_updates        | 725298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5380     |
# |    fps              | 96       |
# |    time_elapsed     | 30489    |
# |    total_timesteps  | 2953567  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 725891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5384     |
# |    fps              | 96       |
# |    time_elapsed     | 30508    |
# |    total_timesteps  | 2956249  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 726562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5388     |
# |    fps              | 96       |
# |    time_elapsed     | 30525    |
# |    total_timesteps  | 2958597  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00385  |
# |    n_updates        | 727149   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5392     |
# |    fps              | 96       |
# |    time_elapsed     | 30544    |
# |    total_timesteps  | 2961330  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00525  |
# |    n_updates        | 727832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5396     |
# |    fps              | 96       |
# |    time_elapsed     | 30562    |
# |    total_timesteps  | 2963968  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00798  |
# |    n_updates        | 728491   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 595      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5400     |
# |    fps              | 97       |
# |    time_elapsed     | 30576    |
# |    total_timesteps  | 2965907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00711  |
# |    n_updates        | 728976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5404     |
# |    fps              | 97       |
# |    time_elapsed     | 30595    |
# |    total_timesteps  | 2968678  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0099   |
# |    n_updates        | 729669   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 607      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5408     |
# |    fps              | 97       |
# |    time_elapsed     | 30616    |
# |    total_timesteps  | 2971703  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00683  |
# |    n_updates        | 730425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 610      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5412     |
# |    fps              | 97       |
# |    time_elapsed     | 30632    |
# |    total_timesteps  | 2973845  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 730961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 609      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5416     |
# |    fps              | 97       |
# |    time_elapsed     | 30650    |
# |    total_timesteps  | 2976493  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00653  |
# |    n_updates        | 731623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5420     |
# |    fps              | 97       |
# |    time_elapsed     | 30665    |
# |    total_timesteps  | 2978583  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00699  |
# |    n_updates        | 732145   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 595      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5424     |
# |    fps              | 97       |
# |    time_elapsed     | 30683    |
# |    total_timesteps  | 2981151  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00931  |
# |    n_updates        | 732787   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 599      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5428     |
# |    fps              | 97       |
# |    time_elapsed     | 30701    |
# |    total_timesteps  | 2983732  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 733432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 595      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5432     |
# |    fps              | 97       |
# |    time_elapsed     | 30715    |
# |    total_timesteps  | 2985722  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 733930   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 599      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5436     |
# |    fps              | 97       |
# |    time_elapsed     | 30732    |
# |    total_timesteps  | 2988205  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 734551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 606      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5440     |
# |    fps              | 97       |
# |    time_elapsed     | 30753    |
# |    total_timesteps  | 2991132  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00682  |
# |    n_updates        | 735282   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 605      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5444     |
# |    fps              | 97       |
# |    time_elapsed     | 30770    |
# |    total_timesteps  | 2993594  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 735898   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5448     |
# |    fps              | 97       |
# |    time_elapsed     | 30783    |
# |    total_timesteps  | 2995478  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 736369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5452     |
# |    fps              | 97       |
# |    time_elapsed     | 30798    |
# |    total_timesteps  | 2997529  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 736882   |
# ----------------------------------

# %%
print("\n--- Iniciando Treino COM Blur ---")
env_blur = make_training_env(with_blur=True, change = 'white_patch', log_dir=log_dir_patch)
# model_blur = DQN("CnnPolicy", env_blur, verbose=1, buffer_size=50_000, learning_starts=10_000, train_freq=4)
model_blur = DQN("CnnPolicy", 
    env_normal, 
    verbose=1,buffer_size=100_000,  
    optimize_memory_usage=False,
    learning_starts=50_000,
    learning_rate=1e-4,
    batch_size=32,
    exploration_fraction=0.1,
    exploration_final_eps=0.01,
    train_freq=4,
    target_update_interval=1000,
    gradient_steps=1)

model_blur.learn(total_timesteps=steps) # Baixo para teste rápido
model_blur.save("dqn_breakout_blur")
env_blur.close()
# Out:
# --- Iniciando Treino COM Blur ---
# Using cpu device
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\buffers.py:242: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.65GB > 4.99GB
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 17
#       3 # model_blur = DQN("CnnPolicy", env_blur, verbose=1, buffer_size=50_000, learning_starts=10_000, train_freq=4)
#       4 model_blur = DQN("CnnPolicy",
#       5     env_normal,
#       6     verbose=1,buffer_size=100_000,
#    (...)
#      14     target_update_interval=1000,
#      15     gradient_steps=1)
# ---> 17 model_blur.learn(total_timesteps=steps) # Baixo para teste rápido
#      18 model_blur.save("dqn_breakout_blur")
#      19 env_blur.close()
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\dqn\dqn.py:272, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     263 def learn(
#     264     self: SelfDQN,
#     265     total_timesteps: int,
#    (...)
#     270     progress_bar: bool = False,
#     271 ) -> SelfDQN:
# --> 272     return super().learn(
#     273         total_timesteps=total_timesteps,
#     274         callback=callback,
#     275         log_interval=log_interval,
#     276         tb_log_name=tb_log_name,
#     277         reset_num_timesteps=reset_num_timesteps,
#     278         progress_bar=progress_bar,
#     279     )
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:335, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     332 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     334 while self.num_timesteps < total_timesteps:
# --> 335     rollout = self.collect_rollouts(
#     336         self.env,
#     337         train_freq=self.train_freq,
#     338         action_noise=self.action_noise,
#     339         callback=callback,
#     340         learning_starts=self.learning_starts,
#     341         replay_buffer=self.replay_buffer,
#     342         log_interval=log_interval,
#     343     )
#     345     if not rollout.continue_training:
#     346         break
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:567, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     564 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     566 # Rescale and perform action
# --> 567 new_obs, rewards, dones, infos = env.step(actions)
#     569 self.num_timesteps += env.num_envs
#     570 num_collected_steps += 1
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:39, in VecFrameStack.step_wait(self)
#      31 def step_wait(
#      32     self,
#      33 ) -> tuple[
#    (...)
#      37     list[dict[str, Any]],
#      38 ]:
# ---> 39     observations, rewards, dones, infos = self.venv.step_wait()
#      40     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      41     return observations, rewards, dones, infos
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\monitor.py:108, in Monitor.step(self, action)
#     106     ep_info.update(self.current_reset_info)
#     107     if self.results_writer:
# --> 108         self.results_writer.write_row(ep_info)
#     109     info["episode"] = ep_info
#     110 self.total_steps += 1
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\monitor.py:210, in ResultsWriter.write_row(self, epinfo)
#     204 """
#     205 Write row of monitor data to csv log file.
#     206
#     207 :param epinfo: the information on episodic return, length, and time
#     208 """
#     209 if self.logger:
# --> 210     self.logger.writerow(epinfo)
#     211     self.file_handler.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# --> 154     return self.writer.writerow(self._dict_to_list(rowdict))
#
# ValueError: I/O operation on closed file.

# %%
# Configuração
steps_por_zona = 1_000_000  # Ajuste conforme seu tempo disponível
zonas = ['top', 'middle', 'bottom']

for zona in zonas:
    print(f"\n=============================================")
    print(f" INICIANDO TREINO: ZONA {zona.upper()}")
    print(f"=============================================")
    
    # Define diretório de log específico para não misturar
    log_dir = f"./logs_hipotese_{zona}/"
    
    # Cria ambiente na zona específica
    env = make_training_env(with_blur=True, change='white_patch', zone=zona, log_dir=log_dir)
    
    # Cria Modelo DQN (Configuração Otimizada que definimos antes)
    model = DQN(
        "CnnPolicy", 
        env, 
        verbose=1,buffer_size=100_000,
        optimize_memory_usage=False,
        learning_starts=50_000,
        learning_rate=1e-4,
        batch_size=32,
        exploration_fraction=0.1,
        exploration_final_eps=0.01,
        train_freq=4,
        target_update_interval=1000,
        gradient_steps=1
        )
    
    # Treina
    model.learn(total_timesteps=steps_por_zona)
    
    # Salva com nome distinto
    model.save(f"dqn_breakout_zone_{zona}")
    
    env.close()
    print(f"Modelo da zona {zona} salvo com sucesso!")

print("\n--- Todos os experimentos finalizados ---")
# Out:
# =============================================
#  INICIANDO TREINO: ZONA TOP
# =============================================
# Using cpu device
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\buffers.py:242: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.65GB > 5.36GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1491     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 776      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 2.12     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1483     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1466     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 1.69     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1477     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1475     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1415     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.64     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1414     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1411     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1419     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1424     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.64     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1429     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1431     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.52     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1440     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1441     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1443     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1448     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1453     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1457     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1461     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 14136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1465     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1468     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 15641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1470     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1471     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 17028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1472     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1471     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1472     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 18964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1474     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1472     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 20397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1473     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1474     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1473     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1471     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 23334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1471     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1473     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1472     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 25426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1474     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 26228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1474     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1475     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 27893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.29     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1475     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1474     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 29443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1475     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1475     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1474     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 31577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1473     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 32168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1473     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 32696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1472     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 33268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1473     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 34176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1472     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 34804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1472     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 35480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1473     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 36319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1474     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 37329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1475     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 37974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1476     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 38721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1476     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 39453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1477     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 40496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1477     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 41185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1477     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 41825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1477     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 42463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1477     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 43303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1479     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 44100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1479     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 44809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1479     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 45538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1478     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 46365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1479     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 47113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1477     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 47841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1476     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 48670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1476     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 49502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1452     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 50104    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.88e-05 |
# |    n_updates        | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1308     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 50824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.86e-05 |
# |    n_updates        | 205      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1169     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 51727    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.63e-05 |
# |    n_updates        | 431      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1076     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 52464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.61e-05 |
# |    n_updates        | 615      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 992      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 53282    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 820      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 914      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 54216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 1053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 857      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 55014    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08e-05 |
# |    n_updates        | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 1.63     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 796      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 56028    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000155 |
# |    n_updates        | 1506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 757      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 56769    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58e-05 |
# |    n_updates        | 1692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 1.64     |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 716      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 57691    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000129 |
# |    n_updates        | 1922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 1.63     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 686      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 58456    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 2113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 1.66     |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 656      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 59306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000104 |
# |    n_updates        | 2326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 632      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 60060    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 2514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 605      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 60982    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11e-05 |
# |    n_updates        | 2745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 1.68     |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 585      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 61781    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000279 |
# |    n_updates        | 2945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 1.76     |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 562      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 62725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00624  |
# |    n_updates        | 3181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 1.81     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 541      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 63710    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000333 |
# |    n_updates        | 3427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 526      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 64482    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 3620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 511      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 65358    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00092  |
# |    n_updates        | 3839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 1.82     |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 499      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 66059    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000988 |
# |    n_updates        | 4014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | 1.86     |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 483      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 67101    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000366 |
# |    n_updates        | 4275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 469      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 68156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0043   |
# |    n_updates        | 4538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 1.97     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 456      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 69120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00556  |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 447      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 69948    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000661 |
# |    n_updates        | 4986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 436      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 70853    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 5213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 427      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 71737    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00502  |
# |    n_updates        | 5434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 418      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 72654    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00981  |
# |    n_updates        | 5663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 2.01     |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 409      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 73638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 5909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 403      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 74395    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000332 |
# |    n_updates        | 6098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 1.99     |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 395      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 75346    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00132  |
# |    n_updates        | 6336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 390      |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 76041    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 6510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 1.93     |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 383      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 76925    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000459 |
# |    n_updates        | 6731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 1.87     |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 377      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 77794    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00638  |
# |    n_updates        | 6948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 1.94     |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 370      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 78947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0015   |
# |    n_updates        | 7236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.209    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 364      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 79925    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00544  |
# |    n_updates        | 7481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 359      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 80806    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000732 |
# |    n_updates        | 7701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 2.02     |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 353      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 81840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000544 |
# |    n_updates        | 7959     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 2.25     |
# |    exploration_rate | 0.176    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 346      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 83254    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 8313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 2.25     |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 341      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 84271    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000391 |
# |    n_updates        | 8567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 2.32     |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 335      |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 85476    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00677  |
# |    n_updates        | 8868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 2.26     |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 330      |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 86422    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0036   |
# |    n_updates        | 9105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | 2.26     |
# |    exploration_rate | 0.133    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 325      |
# ...
# |    loss             | 0.00902  |
# |    n_updates        | 226184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 7.03     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2492     |
# |    fps              | 140      |
# |    time_elapsed     | 6807     |
# |    total_timesteps  | 957710   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000941 |
# |    n_updates        | 226927   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 6.94     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2496     |
# |    fps              | 140      |
# |    time_elapsed     | 6816     |
# |    total_timesteps  | 958908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000487 |
# |    n_updates        | 227226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 140      |
# |    time_elapsed     | 6827     |
# |    total_timesteps  | 960430   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00283  |
# |    n_updates        | 227607   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 7.01     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2504     |
# |    fps              | 140      |
# |    time_elapsed     | 6840     |
# |    total_timesteps  | 962082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000343 |
# |    n_updates        | 228020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 7.01     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2508     |
# |    fps              | 140      |
# |    time_elapsed     | 6852     |
# |    total_timesteps  | 963603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 228400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2512     |
# |    fps              | 140      |
# |    time_elapsed     | 6874     |
# |    total_timesteps  | 966461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00144  |
# |    n_updates        | 229115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 6.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2516     |
# |    fps              | 140      |
# |    time_elapsed     | 6885     |
# |    total_timesteps  | 967907   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0075   |
# |    n_updates        | 229476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 7.08     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2520     |
# |    fps              | 140      |
# |    time_elapsed     | 6900     |
# |    total_timesteps  | 969882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00407  |
# |    n_updates        | 229970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2524     |
# |    fps              | 140      |
# |    time_elapsed     | 6911     |
# |    total_timesteps  | 971321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00398  |
# |    n_updates        | 230330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 427      |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2528     |
# |    fps              | 140      |
# |    time_elapsed     | 6921     |
# |    total_timesteps  | 972666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00275  |
# |    n_updates        | 230666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2532     |
# |    fps              | 140      |
# |    time_elapsed     | 6932     |
# |    total_timesteps  | 974041   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000797 |
# |    n_updates        | 231010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 7.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2536     |
# |    fps              | 140      |
# |    time_elapsed     | 6941     |
# |    total_timesteps  | 975338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000874 |
# |    n_updates        | 231334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2540     |
# |    fps              | 140      |
# |    time_elapsed     | 6967     |
# |    total_timesteps  | 978626   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0031   |
# |    n_updates        | 232156   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 442      |
# |    ep_rew_mean      | 7.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2544     |
# |    fps              | 140      |
# |    time_elapsed     | 6978     |
# |    total_timesteps  | 980187   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00325  |
# |    n_updates        | 232546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2548     |
# |    fps              | 140      |
# |    time_elapsed     | 6990     |
# |    total_timesteps  | 981708   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000375 |
# |    n_updates        | 232926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2552     |
# |    fps              | 140      |
# |    time_elapsed     | 6999     |
# |    total_timesteps  | 982950   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00172  |
# |    n_updates        | 233237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2556     |
# |    fps              | 140      |
# |    time_elapsed     | 7027     |
# |    total_timesteps  | 986692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00283  |
# |    n_updates        | 234172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 7.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2560     |
# |    fps              | 140      |
# |    time_elapsed     | 7037     |
# |    total_timesteps  | 988000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00409  |
# |    n_updates        | 234499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2564     |
# |    fps              | 140      |
# |    time_elapsed     | 7053     |
# |    total_timesteps  | 990251   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.008    |
# |    n_updates        | 235062   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2568     |
# |    fps              | 140      |
# |    time_elapsed     | 7061     |
# |    total_timesteps  | 991353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00408  |
# |    n_updates        | 235338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 7.26     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2572     |
# |    fps              | 140      |
# |    time_elapsed     | 7096     |
# |    total_timesteps  | 995311   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 236327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 473      |
# |    ep_rew_mean      | 7.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2576     |
# |    fps              | 140      |
# |    time_elapsed     | 7110     |
# |    total_timesteps  | 996994   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 236748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 7.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 140      |
# |    time_elapsed     | 7126     |
# |    total_timesteps  | 999014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0042   |
# |    n_updates        | 237253   |
# ----------------------------------
# Modelo da zona middle salvo com sucesso!
#
# =============================================
#  INICIANDO TREINO: ZONA BOTTOM
# =============================================
# Using cpu device
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[34], line 17
#      14 env = make_training_env(with_blur=True, change='white_patch', zone=zona, log_dir=log_dir)
#      16 # Cria Modelo DQN (Configuração Otimizada que definimos antes)
# ---> 17 model = DQN(
#      18     "CnnPolicy",
#      19     env,
#      20     verbose=1,buffer_size=100_000,
#      21     optimize_memory_usage=False,
#      22     learning_starts=50_000,
#      23     learning_rate=1e-4,
#      24     batch_size=32,
#      25     exploration_fraction=0.1,
#      26     exploration_final_eps=0.01,
#      27     train_freq=4,
#      28     target_update_interval=1000,
#      29     gradient_steps=1
#      30     )
#      32 # Treina
#      33 model.learn(total_timesteps=steps_por_zona)
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\dqn\dqn.py:144, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, n_steps, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     141 self.exploration_rate = 0.0
#     143 if _init_setup_model:
# --> 144     self._setup_model()
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\dqn\dqn.py:147, in DQN._setup_model(self)
#     146 def _setup_model(self) -> None:
# --> 147     super()._setup_model()
#     148     self._create_aliases()
#     149     # Copy running stats, see GH issue #996
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:196, in OffPolicyAlgorithm._setup_model(self)
#     194         assert self.env is not None, "You must pass an environment when using `HerReplayBuffer`"
#     195         replay_buffer_kwargs["env"] = self.env
# --> 196     self.replay_buffer = self.replay_buffer_class(
#     197         self.buffer_size,
#     198         self.observation_space,
#     199         self.action_space,
#     200         device=self.device,
#     201         n_envs=self.n_envs,
#     202         optimize_memory_usage=self.optimize_memory_usage,
#     203         **replay_buffer_kwargs,
#     204     )
#     206 self.policy = self.policy_class(
#     207     self.observation_space,
#     208     self.action_space,
#     209     self.lr_schedule,
#     210     **self.policy_kwargs,
#     211 )
#     212 self.policy = self.policy.to(self.device)
#
# File c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\stable_baselines3\common\buffers.py:217, in ReplayBuffer.__init__(self, buffer_size, observation_space, action_space, device, n_envs, optimize_memory_usage, handle_timeout_termination)
#     213 self.observations = np.zeros((self.buffer_size, self.n_envs, *self.obs_shape), dtype=observation_space.dtype)
#     215 if not optimize_memory_usage:
#     216     # When optimizing memory, `observations` contains also the next observation
# --> 217     self.next_observations = np.zeros((self.buffer_size, self.n_envs, *self.obs_shape), dtype=observation_space.dtype)
#     219 self.actions = np.zeros(
#     220     (self.buffer_size, self.n_envs, self.action_dim), dtype=self._maybe_cast_dtype(action_space.dtype)
#     221 )
#     223 self.rewards = np.zeros((self.buffer_size, self.n_envs), dtype=np.float32)
#
# MemoryError: Unable to allocate 2.63 GiB for an array with shape (100000, 1, 4, 84, 84) and data type uint8

# %%
def get_latest_log_file(folder):
    """
    Busca na pasta o arquivo monitor*.csv mais recente (baseado na data de modificação).
    """
    # Procura por monitor.csv, monitor_2023....csv, etc.
    search_path = os.path.join(folder, "monitor*.csv")
    files = glob.glob(search_path)
    
    if not files:
        print(f"Aviso: Nenhum arquivo 'monitor*.csv' encontrado em {folder}")
        return None
    
    # Ordena pelo tempo de modificação (o último é o mais recente)
    latest_file = max(files, key=os.path.getmtime)
    print(f"Lendo log mais recente em '{folder}': {os.path.basename(latest_file)}")
    return latest_file

# %%
def plot_comparison(log_dir_1, name_1, log_dir_2, name_2):
    plt.figure(figsize=(12, 6))
    
    # Função interna para ler dados usando o helper
    def read_data(folder):
        file_path = get_latest_log_file(folder)
        if file_path is None:
            return None, None

        df = pd.read_csv(file_path, skiprows=1)
        if df.empty: return None, None
        
        x = df['l'].cumsum() # Steps acumulados
        y = df['r']          # Recompensa
        # Suavização (Média móvel de 100 episódios)
        y_smooth = y.rolling(window=100).mean()
        return x, y_smooth

    # Plota o Primeiro
    x1, y1 = read_data(log_dir_1)
    if x1 is not None:
        plt.plot(x1, y1, label=name_1, color='blue', linewidth=2)

    # Plota o Segundo
    x2, y2 = read_data(log_dir_2)
    if x2 is not None:
        plt.plot(x2, y2, label=name_2, color='red', linewidth=2, linestyle='--')

    plt.xlabel('Timesteps (Passos)')
    plt.ylabel('Recompensa Média (Média Móvel 100 ep)')
    plt.title('Comparação de Performance: Normal vs Oclusão')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
plot_comparison("./logs_clean/", "Normal (Sem Mancha)", "./logs_patch/", "Com Mancha Branca")
# Out:
# Lendo log mais recente em './logs_clean/': monitor.csv
# Lendo log mais recente em './logs_patch/': monitor.csv

# %%
def plot_advanced_analysis(log_dir_1, name_1, log_dir_2, name_2):
    
    def read_dataframe(folder):
        file_path = get_latest_log_file(folder)
        if file_path is None:
            return None
        # Pula as duas primeiras linhas (header do SB3)
        try:
            df = pd.read_csv(file_path, skiprows=1)
            return df
        except Exception as e:
            print(f"Erro ao ler {file_path}: {e}")
            return None

    df1 = read_dataframe(log_dir_1)
    df2 = read_dataframe(log_dir_2)

    if df1 is None and df2 is None:
        print("Nenhum dado válido encontrado para plotar.")
        return

    # Cria uma figura com 3 subgráficos (gridspec para layout bonito)
    fig = plt.figure(figsize=(15, 10))
    gs = fig.add_gridspec(2, 2)
    
    # --- GRÁFICO 1: RECOMPENSA (Média Móvel) ---
    ax1 = fig.add_subplot(gs[0, :]) # Ocupa a linha inteira superior
    window = 100
    
    if df1 is not None and not df1.empty:
        x1 = df1['l'].cumsum()
        y1 = df1['r'].rolling(window=window).mean()
        ax1.plot(x1, y1, label=f"{name_1}", color='blue')
        std1 = df1['r'].rolling(window=window).std()
        ax1.fill_between(x1, y1-std1, y1+std1, color='blue', alpha=0.1)

    if df2 is not None and not df2.empty:
        x2 = df2['l'].cumsum()
        y2 = df2['r'].rolling(window=window).mean()
        ax1.plot(x2, y2, label=f"{name_2}", color='red', linestyle='--')
        std2 = df2['r'].rolling(window=window).std()
        ax1.fill_between(x2, y2-std2, y2+std2, color='red', alpha=0.1)

    ax1.set_title("1. Curva de Aprendizado (Recompensa Média)")
    ax1.set_ylabel("Pontos no Breakout")
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # --- GRÁFICO 2: DURAÇÃO DO EPISÓDIO (Sobrevivência) ---
    ax2 = fig.add_subplot(gs[1, 0])
    
    if df1 is not None and not df1.empty:
        y1_len = df1['l'].rolling(window=window).mean()
        ax2.plot(x1, y1_len, color='blue')

    if df2 is not None and not df2.empty:
        y2_len = df2['l'].rolling(window=window).mean()
        ax2.plot(x2, y2_len, color='red', linestyle='--')
        
    ax2.set_title("2. Sobrevivência (Duração do Jogo)")
    ax2.set_ylabel("Frames por Episódio")
    ax2.set_xlabel("Total Timesteps")
    ax2.grid(True, alpha=0.3)
    
    # --- GRÁFICO 3: VELOCIDADE DE TREINO (FPS Real) ---
    ax3 = fig.add_subplot(gs[1, 1])
    
    if df1 is not None and not df1.empty:
        fps1 = x1.iloc[-1] / df1['t'].iloc[-1]
        ax3.bar(name_1, fps1, color='blue', alpha=0.6)
        ax3.text(name_1, fps1, f"{int(fps1)} FPS", ha='center', va='bottom')

    if df2 is not None and not df2.empty:
        fps2 = x2.iloc[-1] / df2['t'].iloc[-1]
        ax3.bar(name_2, fps2, color='red', alpha=0.6)
        ax3.text(name_2, fps2, f"{int(fps2)} FPS", ha='center', va='bottom')

    ax3.set_title("3. Velocidade de Treinamento (FPS)")
    ax3.set_ylabel("Frames por Segundo")

    plt.tight_layout()
    plt.show()

# %%
# Chama a função comparando as pastas que criamos antes
plot_advanced_analysis("./logs_clean/", "Sem Mancha", "./logs_patch/", "Com Mancha")
# Out:
# Lendo log mais recente em './logs_clean/': monitor.csv
# Lendo log mais recente em './logs_patch/': monitor.csv

# %%
def record_video(model, name_prefix, with_blur, change='white_patch', zone='middle', n_episodes=1, max_steps=3000):
    video_folder = "./videos/"
    os.makedirs(video_folder, exist_ok=True)
    
    print(f"--- Gravando {name_prefix} [Zona: {zone}] (Max {max_steps} steps) ---")

    # Coordenadas das zonas (Devem ser IDÊNTICAS ao treino)
    presets = {
        'top':    (27, 10, 30, 30),
        'middle': (27, 40, 30, 30),
        'bottom': (27, 54, 30, 30)
    }
    region = presets.get(zone, (27, 40, 30, 30))

    def _create_video_env():
        env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
        env = FireResetEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        
        # Aplica a mancha na zona correta
        if change == 'white_patch':
            env = WhitePatchBreakout(env, apply_patch=with_blur, region=region)
        elif change == 'blur':
            env = BlurBreakout(env, apply_blur=with_blur, region=region, ksize=21)
        
        env = gym.wrappers.RecordVideo(
            env, 
            video_folder=video_folder, 
            name_prefix=name_prefix,
            episode_trigger=lambda x: True,
            disable_logger=True
        )
        
        env = GrayscaleWrapper(env)
        return env

    env = DummyVecEnv([_create_video_env])
    env = VecTransposeImage(env)
    env = VecFrameStack(env, n_stack=4)

    obs = env.reset()
    episodes_count = 0
    current_steps = 0
    last_lives = 5 
    
    try:
        while episodes_count < n_episodes:
            action, _ = model.predict(obs, deterministic=True)
            
            # --- Anti-Stuck: Força FIRE se ficar parado demais ---
            # (Mantenha sua lógica de vidas ou use um contador de ações repetidas)
            
            obs, rewards, done, infos = env.step(action)
            current_steps += 1
            
            # Checagem de vidas para atualizar last_lives
            for info in infos:
                lives = info.get("lives", 0)
                if lives < last_lives:
                    last_lives = lives
            
            if current_steps > max_steps:
                print(f"ALERTA: Episódio excedeu {max_steps} passos. Forçando parada.")
                done = [True]
            
            for i, d in enumerate(done):
                if d:
                    episodes_count += 1
                    current_steps = 0
                    last_lives = 5
                    score = infos[i].get('episode', {}).get('r', 0)
                    print(f"Episódio {episodes_count} finalizado | Score: {score}")
                    obs = env.reset()
                    
    except KeyboardInterrupt:
        print("Interrompido.")
    finally:
        env.close()
        print(f"Vídeos salvos em {video_folder}")

# %%
if os.path.exists("dqn_breakout_zone_top.zip"):
    print(">>> Carregando Modelo TOP...")
    model_top = DQN.load("dqn_breakout_zone_top")
    
    record_video(
        model=model_top, 
        name_prefix="video_teste_TOP", 
        with_blur=True, 
        change='white_patch', 
        zone='top',  # <--- IMPORTANTE: Mudar para 'top'
        n_episodes=2
    )
# Out:
# >>> Carregando Modelo TOP...
# --- Gravando video_teste_TOP [Zona: top] (Max 3000 steps) ---
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\user\Documents\mestrado\BlurRL\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episódio 1 finalizado | Score: 0
# Episódio 2 finalizado | Score: 0
# Vídeos salvos em ./videos/

# %%
if os.path.exists("dqn_breakout_zone_middle.zip"): # Ou o nome que você usou antes
    print("\n>>> Carregando Modelo MIDDLE...")
    model_middle = DQN.load("dqn_breakout_zone_middle")
    
    record_video(
        model=model_middle, 
        name_prefix="video_teste_MIDDLE", 
        with_blur=True, 
        change='white_patch', 
        zone='middle', 
        n_episodes=2
    )
# Out:
# >>> Carregando Modelo MIDDLE...
# --- Gravando video_teste_MIDDLE [Zona: middle] (Max 3000 steps) ---
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 1 finalizado | Score: 0
# Episódio 2 finalizado | Score: 0
# Vídeos salvos em ./videos/

# %%
record_video(model_blur, "teste_com_blur", with_blur=True, change = 'white_patch', n_episodes=5)
# Out:
# --- Gravando teste_com_blur (Max 3000 steps) ---
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 1 finalizado | Score: 0
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 2 finalizado | Score: 0
# Episódio 3 finalizado | Score: 0
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 4 finalizado | Score: 0
# ALERTA: Episódio excedeu 3000 passos. Forçando parada.
# Episódio 5 finalizado | Score: 0
# Vídeos salvos em ./videos/

# %%
record_video(model_normal, "teste_sem_blur", with_blur=False, change = 'white_patch', n_episodes=5, max_steps=100_000)
# Out:
# --- Gravando teste_sem_blur (Max 100000 steps) ---
# c:\Users\user\Documents\mestrado\BlurRL\.venv\lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at c:\Users\user\Documents\mestrado\BlurRL\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episódio 1 finalizado | Score: 0
# Episódio 2 finalizado | Score: 0
# Episódio 3 finalizado | Score: 0
# Episódio 4 finalizado | Score: 0
# Episódio 5 finalizado | Score: 0
# Vídeos salvos em ./videos/
